# %%
import os
import openai
from langchain.llms import AzureOpenAI

# Azure OpenAI configuration
OPENAI_API_TYPE = "Azure"
OPENAI_API_VERSION = "2022-12-01"
OPENAI_API_BASE = "https://bg.openai.azure.com/"
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "ed610003b55340b3a1d243008ef2c437") 
DEPLOYMENT_NAME = "GPT-35-0301"

# Set environment variables (if not already set in your environment)
os.environ["AZURE_OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["OPENAI_API_VERSION"] = OPENAI_API_VERSION
os.environ["AZURE_OPENAI_ENDPOINT"] = OPENAI_API_BASE

# Verify the environment variables are set
print("API Key:", os.getenv("AZURE_OPENAI_API_KEY"))
print("API Version:", os.getenv("OPENAI_API_VERSION"))
print("API Endpoint:", os.getenv("AZURE_OPENAI_ENDPOINT"))

# Ensure the API key and endpoint are set correctly
if not OPENAI_API_KEY:
    raise ValueError("API key is missing. Please set the AZURE_OPENAI_API_KEY environment variable.")
if not OPENAI_API_BASE:
    raise ValueError("API base URL is missing. Please set the AZURE_OPENAI_ENDPOINT environment variable.")

# Configure the OpenAI API client
openai.api_type = OPENAI_API_TYPE
openai.api_base = OPENAI_API_BASE
openai.api_version = OPENAI_API_VERSION
openai.api_key = OPENAI_API_KEY

# Initialize the AzureOpenAI object with the required credentials, api_version, and azure_endpoint
llm = AzureOpenAI(
        openai_api_key=OPENAI_API_KEY,
        deployment_name="GPT-35-0301",
        model_name="GPT-35-0301",
        openai_api_version=OPENAI_API_VERSION,
        azure_endpoint=OPENAI_API_BASE
    )
# Out:
# API Key: ed610003b55340b3a1d243008ef2c437
# API Version: 2022-12-01
# API Endpoint: https://bg.openai.azure.com/
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The class `AzureOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import AzureOpenAI`.
#   warn_deprecated(

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
files=os.listdir('D:\\Resumes')

# %%
#file reading
files=os.listdir('D:\\resume')
file_path = "D:\\resume\\"+files[0]

# Open and read the file with UTF-8 encoding
l=[]
with open(file_path, 'r', encoding='utf-8') as file:
    df = file.read()
    print(df)
# Out:
# Aritra Adhya
# aritraadhya1@gmail.com
# 8617245605
# 2137 Nayabad Mukundapur, Kolkata, India
# linkedin.com/in/aritraadhya
# github.com/Aritraadhya
# EDUCATION
# Master of Computer Application
# Jadavpur University
# 2022 - 2024
# ,
#
# 8.24CGPA
# Bachelor of Mathematics
# Jogesh Chandra Chaudhuri College
# 2017 - 2021
# ,
#
# 68.625%
# Higher Secondary Examination
# Kalyani Central Model School
# 2015 - 2017
# ,
#
# 70.8%
# Secondary Examination
# Nava Nalanda School
# 2014 - 2015
# ,
#
# 77%
# PERSONAL PROJECTS
# Quiz App
#
#
# The project loads questions from open trivia db and creates an
# interface for the user to answer questions and see the number of
# correct and incorrect answers.It uses HTML,CSS,JS,Bootstrap.
# Covid 19 detection using Multiscale CNN
#
#
# The project read the dataset and train a model to identify covid and
# non covid images and determine the accuracy using Multiscale CNN
# and plot ROC curve and confusion matrix.It use NumPy , Pandas ,
# ...

# %%
#file reading
files=os.listdir('D:\\resume')
file_path = "D:\\resume\\"+files[1]

# Open and read the file with UTF-8 encoding
l=[]
with open(file_path, 'r', encoding='utf-8') as file:
    df1 = file.read()
    print(df1)
# Out:
# NILESH KUNDU
# Student at Jadavpur University
# Looking forward to working with an organization where I can
# contribute my knowledge and training to enrich my professional
# experience in a real environment outside the academic ﬁeld.
#
# nileshkundu2@gmail.com
# 9382835462
# kolkata,India
# linkedin.com/in/nilesh-kundu
# github.com/ni1eshkundu
# EDUCATION
# Master of Computer Application
# Jadavpur University
#
#
# 09/2022 - Present
# ,
#
# Kolkata
# B.Sc in Computer Science
# J.K College, Purulia
# 07/2019 - 07/2022
# ,
#
# CGPA-9.48
# Higher Secondary Education
# Chittaranjan High School, Purulia
# 07/2017 - 05/2019
# ,
#
# 72.8%
# PROJECTS
# Real-Time Chat Application
#  (08/2023 - 09/2023)
#
#
# An intuitive real-time chat room application focused on seamless
# communication.
# It's providing a straightforward and eﬃcient platform for users to
# connect and chat.
# Technology used -
# React.js , CSS , Vs Code ,Appwrite.
#
# Design a University Website
#  (03/2022 - 06/2022)
#
#
# ...

# %%
#file reading
files=os.listdir('D:\\resume')
file_path = "D:\\resume\\"+files[2]

# Open and read the file with UTF-8 encoding
l=[]
with open(file_path, 'r', encoding='utf-8') as file:
    df2 = file.read()
    print(df2)
# Out:
# Priyanka Ghosh
# Student at Jadavpur University
# Computer Science Graduate, currently pursuing
# MCA who is passionate about learning new
# technologies and looking forward to roles that
# oﬀer a great learning curve with good career
# progression as a fresher
# priyanka7890mili@gmail.com
# 9875655122
# Kolkata, India
# linkedin.com/in/priyankaghosh25
# github.com/Priyankaghosh25
# EDUCATION
# Master of Computer Application (MCA)
# Jadavpur University
# 09/2022 - 08/2023
# ,
#
# SGPA - 8.67 (upto Sem-II)
# Data Structures and
# Algorithms (DSA)
# Operating System (OS)
# Object Oriented
# Programming (OOPs)
# Database Management
# System (DBMS)
# Computer Networks
# Bachelor of Science (Computer Science)
# Asutosh College ( University of Calcutta )
# 07/2019 - 07/2022
# ,
#
# CGPA- 9.071
# Higher Secondary Examination (WBCHSE)
# Uttarpara Girls' High School, West Bengal
# 2019
# ,
#
# Percentage - 89.2%
# Secondary Examination (WBBSE)
# Uttarpara Children's Own Home, West
# Bengal
# ...

# %%
#file reading
files=os.listdir('D:\\resume')
file_path = "D:\\resume\\"+files[3]

# Open and read the file with UTF-8 encoding
l=[]
with open(file_path, 'r', encoding='utf-8') as file:
    df3 = file.read()
    print(df3)
# Out:
# Rounik Majumder
# Aspiring Full Stack Developer
# I have a diverse skill set in programming languages such as Python,C++,C
# and
# Javascript also have experience in both front-end and back-
# end development. I am passionate about staying up-to-date with the latest trends and technologies in the ﬁeld, and I am always looking for
# new challenges and opportunities to grow as a professional.
# rsmajumder704@gmail.com
# +91 8902370152
# Kolkata, India
# rounik.vercel.app
# linkedin.com/in/rounik-majumder
# github.com/rsmajumder
# EDUCATION
# Jadavpur University
# Master of Computer Application (MCA)
# 2022 - Present
# ,
#
# CGPA : 8.005
# University of Calcutta
# Bachelor of Science | Computer Science
# 2019 - 2022
# ,
#
# CGPA : 8.36
# Nebadhai High School
# 12th
# 2019
# ,
#
# CGPA :
# 8.02
# Nebadhai High School
# 10th
# 2017
# ,
#
# CGPA : 9.1
# PERSONAL PROJECTS
# Build real time authentication system
# USING DJANGO REST API | OAuth 2.0, JWT , OTP system .
# ...

# %%
#file reading
files=os.listdir('D:\\resume')
file_path = "D:\\resume\\"+files[4]

# Open and read the file with UTF-8 encoding
l=[]
with open(file_path, 'r', encoding='utf-8') as file:
    df4 = file.read()
    print(df4)
# Out:
# Siddhant Majumder
# Student at Jadavpur University
# MCA student with dreams of ﬂourishing in the binary realm.
# siddhantmajumder@gmail.com
# 8240884229
# Kolkata
# linkedin.com/in/siddhant-majumder-6301161a1
# github.com/Codeworm08
# EDUCATION
# Master Of Computer Application
# Jadavpur University
#
#
# 11/2022 - Present
# ,
#
# Bachelor Of Science in Computer Science
# St. Xavier's College(Autonomous)
#
#
# 04/2019 - 04/2022
# ,
#
# 8.38 GPA
# PERSONAL PROJECTS
# Podcast Player
#  (10/2023 - 10/2023)
#
#
# Live Link:
#
#
# Fetch and play podcast episodes using rss feed links.
# Made using Node and Reactjs.
# Movie Recommendation
#  (07/2023 - 07/2023)
#
#
# Live Link:
#
#
# Implemented login, favorites and fetching of popular movies in the
# selected genre(s) using TMDB API.
# Technologies used: Reactjs.
# Facebook Scrapper
#  (10/2021 - 04/2022)
#
#
# Designed back-end of the project.
# Extracts posts and reactions from Facebook proﬁle.
# ...

# %%
#file reading
files=os.listdir('D:\\resume')
file_path = "D:\\resume\\"+files[0]

# Open and read the file with UTF-8 encoding
l=[]
with open(file_path, 'r', encoding='utf-8') as file:
    df = file.read()
    print(df)
# Out:
# Aritra Adhya
# aritraadhya1@gmail.com
# 8617245605
# 2137 Nayabad Mukundapur, Kolkata, India
# linkedin.com/in/aritraadhya
# github.com/Aritraadhya
# EDUCATION
# Master of Computer Application
# Jadavpur University
# 2022 - 2024
# ,
#
# 8.24CGPA
# Bachelor of Mathematics
# Jogesh Chandra Chaudhuri College
# 2017 - 2021
# ,
#
# 68.625%
# Higher Secondary Examination
# Kalyani Central Model School
# 2015 - 2017
# ,
#
# 70.8%
# Secondary Examination
# Nava Nalanda School
# 2014 - 2015
# ,
#
# 77%
# PERSONAL PROJECTS
# Quiz App
#
#
# The project loads questions from open trivia db and creates an
# interface for the user to answer questions and see the number of
# correct and incorrect answers.It uses HTML,CSS,JS,Bootstrap.
# Covid 19 detection using Multiscale CNN
#
#
# The project read the dataset and train a model to identify covid and
# non covid images and determine the accuracy using Multiscale CNN
# and plot ROC curve and confusion matrix.It use NumPy , Pandas ,
# ...

# %%
#data extraction from this file
#from pytesseract
import re
import PyPDF2

def extract_text_from_pdf(pdf_path):
    try:
        with open(pdf_path, 'rb') as file:
            pdf_reader = PyPDF2.PdfReader(file)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text() + '\n'
            return text
    except PyPDF2.errors.PdfReadError as e:
        return f"Error reading PDF: {e}"
    except Exception as e:
        return f"An error occurred: {e}"

def extract_data_with_questions(text, questions):
    extracted_data = {}
    for question in questions:
        # Create a pattern to match potential answers following the question
        pattern = re.compile(rf'{re.escape(question)}\s*:\s*(.*)', re.IGNORECASE)
        match = pattern.search(text)
        if match:
            extracted_data[question] = match.group(1).strip()
        else:
            extracted_data[question] = 'Not found'
    return extracted_data
# Example usage
extracted_text=[]
files=os.listdir("D:\\Resumes")
for i in range(len(files)):
    pdf_path = "D:\\Resumes\\"+files[i]  # Replace with your PDF file path
#prompts = ['Klasse', 'Erw', 'Hinfahrt', 'Gültig ab','Auftragsnummer','Über: VIA']  # Replace with your prompts
    questions = [
    'Klasse',
    'Erw',
    'Gültig ab',
    'Auftragsnummer',
    'Über'
    ]

# Extract text from the PDF
    extracted_text.append(extract_text_from_pdf(pdf_path))
    print(extracted_text[i])

#if "An error occurred" not in extracted_text:
    # Extract data based on questions
 #   extracted_data = extract_data_with_questions(extracted_text, questions)
  #  for question, answer in extracted_data.items():
   #     print(f'{question} {answer}')
#else:
 #   print(extracted_text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 33
#      31 # Example usage
#      32 extracted_text=[]
# ---> 33 files=os.listdir("C:\\Users\\Admin\\Downloads\\Resumes")
#      34 for i in range(len(files)):
#      35     pdf_path = "C:\\Users\\Admin\\Downloads\\Resumes\\"+files[i]  # Replace with your PDF file path
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Admin\\Downloads\\Resumes'

# %%
len(l)
# Out:
# 1

# %%
print(extracted_text[0])
# Out:
# NILESH KUNDU
# Student at Jadavpur University
# Looking forward to working with an organization where I can
# contribute my knowledge and training to enrich my professional
# experience in a real environment outside the academic ﬁeld.
#
# nileshkundu2@gmail.com
# 9382835462
# kolkata,India
# linkedin.com/in/nilesh-kundu
# github.com/ni1eshkundu
# EDUCATION
# Master of Computer Application
# Jadavpur University
#
#
# 09/2022 - Present
# ,
#
# Kolkata
# B.Sc in Computer Science
# J.K College, Purulia
# 07/2019 - 07/2022
# ,
#
# CGPA-9.48
# Higher Secondary Education
# Chittaranjan High School, Purulia
# 07/2017 - 05/2019
# ,
#
# 72.8%
# PROJECTS
# Real-Time Chat Application
#  (08/2023 - 09/2023)
#
#
# An intuitive real-time chat room application focused on seamless
# communication.
# It's providing a straightforward and eﬃcient platform for users to
# connect and chat.
# Technology used -
# React.js , CSS , Vs Code ,Appwrite.
#
# Design a University Website
#  (03/2022 - 06/2022)
#
#
# ...

# %%
print(extracted_text[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(extracted_text[1])
#
# NameError: name 'extracted_text' is not defined

# %%
print(extracted_text[2])
# Out:
# Rounik Majumder
# Aspiring Full Stack Developer
# I have a diverse skill set in programming languages such as Python,C++,C
# and
# Javascript also have experience in both front-end and back-
# end development. I am passionate about staying up-to-date with the latest trends and technologies in the ﬁeld, and I am always looking for
# new challenges and opportunities to grow as a professional.
# rsmajumder704@gmail.com
# +91 8902370152
# Kolkata, India
# rounik.vercel.app
# linkedin.com/in/rounik-majumder
# github.com/rsmajumder
# EDUCATION
# Jadavpur University
# Master of Computer Application (MCA)
# 2022 - Present
# ,
#
# CGPA : 8.005
# University of Calcutta
# Bachelor of Science | Computer Science
# 2019 - 2022
# ,
#
# CGPA : 8.36
# Nebadhai High School
# 12th
# 2019
# ,
#
# CGPA :
# 8.02
# Nebadhai High School
# 10th
# 2017
# ,
#
# CGPA : 9.1
# PERSONAL PROJECTS
# Build real time authentication system
# USING DJANGO REST API | OAuth 2.0, JWT , OTP system .
# ...

# %%
print(extracted_text[3])
# Out:
# Siddhant Majumder
# Student at Jadavpur University
# MCA student with dreams of ﬂourishing in the binary realm.
# siddhantmajumder@gmail.com
# 8240884229
# Kolkata
# linkedin.com/in/siddhant-majumder-6301161a1
# github.com/Codeworm08
# EDUCATION
# Master Of Computer Application
# Jadavpur University
#
#
# 11/2022 - Present
# ,
#
# Bachelor Of Science in Computer Science
# St. Xavier's College(Autonomous)
#
#
# 04/2019 - 04/2022
# ,
#
# 8.38 GPA
# PERSONAL PROJECTS
# Podcast Player
#  (10/2023 - 10/2023)
#
#
# Live Link:
#
#
# Fetch and play podcast episodes using rss feed links.
# Made using Node and Reactjs.
# Movie Recommendation
#  (07/2023 - 07/2023)
#
#
# Live Link:
#
#
# Implemented login, favorites and fetching of popular movies in the
# selected genre(s) using TMDB API.
# Technologies used: Reactjs.
# Facebook Scrapper
#  (10/2021 - 04/2022)
#
#
# Designed back-end of the project.
# Extracts posts and reactions from Facebook proﬁle.
# ...

# %%
print(extracted_text[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 print(extracted_text[4])
#
# IndexError: list index out of range

# %%
print(extracted_text[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(extracted_text[5])
#
# IndexError: list index out of range

# %%
l[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 l[1]
#
# IndexError: list index out of range

# %%
#extract all the necessary details from the above file using LLM model
#name
#email-id
#phone number
#linkden
#github
#education-10th school name year of passing,12th school name year of passing,Master college name year of passing
#personal projects in resume
#skills-technical skills,soft skills

#responsibilities
#certification
#achievements
# Function to extract details using LLM
def get_completion(prompt):
    response = llm(prompt)
    return response
prompt = f"""
    Extract the following details from the resume:

    1. Name:
    2. Email:
    3. Phone number:
    4. LinkedIn:
    5. GitHub:
    6. Education (10th, 12th, Master): 
    7. Personal projects:
    8. Technical skills:
    9. Soft skills:
    10. Responsibilities:
    11. Certifications:
    12. Achievements:

    Please provide the details in the following format:
    Name: <Name>
    Email: <Email>
    Phone number: <Phone>
    LinkedIn: <LinkedIn>
    GitHub: <GitHub>
    Education: <List the education details here>
    Personal projects: <List the projects here>
    Technical skills: <List the technical skills here>
    Soft skills: <List the soft skills here>
    Responsibilities: <List the responsibilities here>
    Certifications: <List the certifications here>
    Achievements: <List the achievements here>
\"\"\"{df1}\"\"\"
"""
response1 = get_completion(prompt)
print(response1)
    




# Use the llm(prompt) function to generate the questions
# Out:
# Name: NILESH KUNDU
# Email: nileshkundu2@gmail.com
# Phone number: 9382835462
# LinkedIn: linkedin.com/in/nilesh-kundu
# GitHub: github.com/ni1eshkundu
# Education:
# Master of Computer Application - Jadavpur University, Kolkata (09/2022 - Present)
# B.Sc in Computer Science - J.K College, Purulia (07/2019 - 07/2022, CGPA-9.48)
# Higher Secondary Education - Chittaranjan High School, Purulia (07/2017 - 05/2019, 72.8%)
# Personal projects:
# 1. Real-Time Chat Application - An intuitive real-time chat room application focused on seamless communication. It's providing a straightforward and eﬃcient platform for users to connect and chat. Technology used - React.js, CSS, Vs Code, Appwrite.
# 2. Design a University Website - It is a website of a university to help students and faculties of the university. Serve as a comprehensive hub for engagement, showcasing offerings and providing essential resources. Technology used - HTML, CSS, PHP, Vs Code, XAMPP.
# Technical skills:
# C, C++,

# %%
#extract all the necessary details from the above file using LLM model
#name
#email-id
#phone number
#linkden
#github
#education-10th school name year of passing,12th school name year of passing,Master college name year of passing
#personal projects in resume
#skills-technical skills,soft skills

#responsibilities
#certification
#achievements
# Function to extract details using LLM
def get_completion(prompt):
    response = llm(prompt)
    return response
prompt = f"""
    Extract the following details from the resume:

    1. Name:
    2. Email:
    3. Phone number:
    4. LinkedIn:
    5. GitHub:
    6. Education (10th, 12th, Master): 
    7. Personal projects:
    8. Technical skills:
    9. Soft skills:
    10. Responsibilities:
    11. Certifications:
    12. Achievements:

    Please provide the details in the following format:
    Name: <Name>
    Email: <Email>
    Phone number: <Phone>
    LinkedIn: <LinkedIn>
    GitHub: <GitHub>
    Education: <List the education details here>
    Personal projects: <List the projects here>
    Technical skills: <List the technical skills here>
    Soft skills: <List the soft skills here>
    Responsibilities: <List the responsibilities here>
    Certifications: <List the certifications here>
    Achievements: <List the achievements here>
\"\"\"{df}\"\"\"
"""
response = get_completion(prompt)
print(response)
# Out:
# Name: Aritra Adhya
# Email: aritraadhya1@gmail.com
# Phone number: 8617245605
# LinkedIn: linkedin.com/in/aritraadhya
# GitHub: github.com/Aritraadhya
# Education:
# Master of Computer Application, Jadavpur University, 2022 - 2024, 8.24CGPA
# Bachelor of Mathematics, Jogesh Chandra Chaudhuri College, 2017 - 2021, 68.625%
# Higher Secondary Examination, Kalyani Central Model School, 2015 - 2017, 70.8%
# Secondary Examination, Nava Nalanda School, 2014 - 2015, 77%
# Personal projects:
# Quiz App
# Covid 19 detection using Multiscale CNN
# Classiﬁcation model
# To do list app
# Tic-tac-toe app
# Technical skills: NumPy, Linux, C, C++, Java, Data Structures and Algorithms, HTML, CSS, Pandas, Bootstrap, Javascript, Python, Machine Learning, My SQL, Github, React.js
# Soft skills: N/A
# Responsibilities: I am a passionate programmer and I the challenge of solving problems with code. I’m always

# %%
text=""

# %%
#extract all the necessary details from the above file using LLM model
#name
#email-id
#phone number
#linkden
#github
#education-10th school name year of passing,12th school name year of passing,Master college name year of passing
#personal projects in resume
#skills-technical skills,soft skills

#responsibilities
#certification
#achievements
# Function to extract details using LLM
def get_completion(prompt):
    response = llm(prompt)
    return response
prompt = f"""
    Extract the following details from the resume:

    1. Name:
    2. Email:
    3. Phone number:
    4. LinkedIn:
    5. GitHub:
    6. Education (10th, 12th, Master): 
    7. Personal projects:
    8. Technical skills:
    9. Soft skills:
    10. Responsibilities:
    11. Certifications:
    12. Achievements:

    Please provide the details in the following format:
    Name: <Name>
    Email: <Email>
    Phone number: <Phone>
    LinkedIn: <LinkedIn>
    GitHub: <GitHub>
    Education: <List the education details here>
    Personal projects: <List the projects here>
    Technical skills: <List the technical skills here>
    Soft skills: <List the soft skills here>
    Responsibilities: <List the responsibilities here>
    Certifications: <List the certifications here>
    Achievements: <List the achievements here>
\"\"\"{df2}\"\"\"
"""
response2 = get_completion(prompt)
print(response2)
# Out:
# Name: Priyanka Ghosh
# Email: priyanka7890mili@gmail.com
# Phone number: 9875655122
# LinkedIn: linkedin.com/in/priyankaghosh25
# GitHub: github.com/Priyankaghosh25
# Education: Priyanka has completed her 10th from Uttarpara Children's Own Home, West Bengal with a percentage of 91.3% and has completed her 12th from Uttarpara Girls' High School, West Bengal with a percentage of 89.2%. She has completed her Bachelor of Science (Computer Science) from Asutosh College with a CGPA of 9.071 and is currently pursuing her Master of Computer Application (MCA) from Jadavpur University with an SGPA of 8.67 (upto Sem-II). The subjects she has studied include Data Structures and Algorithms (DSA), Operating System (OS), Object Oriented Programming (OOPs), Database Management System (DBMS) and Computer Networks.
# ...

# %%
#extract all the necessary details from the above file using LLM model
#name
#email-id
#phone number
#linkden
#github
#education-10th school name year of passing,12th school name year of passing,Master college name year of passing
#personal projects in resume
#skills-technical skills,soft skills

#responsibilities
#certification
#achievements
# Function to extract details using LLM
def get_completion(prompt):
    response = llm(prompt)
    return response
prompt = f"""
    Extract the following details from the resume:

    1. Name:
    2. Email:
    3. Phone number:
    4. LinkedIn:
    5. GitHub:
    6. Education (10th, 12th, Master): 
    7. Personal projects:
    8. Technical skills:
    9. Soft skills:
    10. Responsibilities:
    11. Certifications:
    12. Achievements:

    Please provide the details in the following format:
    Name: <Name>
    Email: <Email>
    Phone number: <Phone>
    LinkedIn: <LinkedIn>
    GitHub: <GitHub>
    Education: <List the education details here>
    Personal projects: <List the projects here>
    Technical skills: <List the technical skills here>
    Soft skills: <List the soft skills here>
    Responsibilities: <List the responsibilities here>
    Certifications: <List the certifications here>
    Achievements: <List the achievements here>
\"\"\"{df3}\"\"\"
"""
response3 = get_completion(prompt)
print(response3)
# Out:
# Name: Rounik Majumder
# Email: rsmajumder704@gmail.com
# Phone number: +91 8902370152
# LinkedIn: linkedin.com/in/rounik-majumder
# GitHub: github.com/rsmajumder
# Education: Master of Computer Application (MCA) | Jadavpur University | 2022 - Present, CGPA : 8.005
# Bachelor of Science | Computer Science | University of Calcutta | 2019 - 2022, CGPA : 8.36
# 12th | Nebadhai High School | 2019, CGPA : 8.02
# 10th | Nebadhai High School | 2017, CGPA : 9.1
# Personal projects:
#     1. Build real time authentication system Using Django REST API | OAuth 2.0, JWT , OTP system .
#     2. Designing Ecommerce Website Using Django | Build Search System , Add to Cart , Show Product, Place to Order .
#     3. Text-To-Speech Using HTML , CSS , JAVASCRIPT | Text to speech multiple language support .
#     4. Real Time Chat Application Using Django | MVT Architecture | Create

# %%
#extract all the necessary details from the above file using LLM model
#name
#email-id
#phone number
#linkden
#github
#education-10th school name year of passing,12th school name year of passing,Master college name year of passing
#personal projects in resume
#skills-technical skills,soft skills

#responsibilities
#certification
#achievements
# Function to extract details using LLM
def get_completion(prompt):
    response = llm(prompt)
    return response
prompt = f"""
    Extract the following details from the resume:

    1. Name:
    2. Email:
    3. Phone number:
    4. LinkedIn:
    5. GitHub:
    6. Education (10th, 12th, Master): 
    7. Personal projects:
    8. Technical skills:
    9. Soft skills:
    10. Responsibilities:
    11. Certifications:
    12. Achievements:

    Please provide the details in the following format:
    Name: <Name>
    Email: <Email>
    Phone number: <Phone>
    LinkedIn: <LinkedIn>
    GitHub: <GitHub>
    Education: <List the education details here>
    Personal projects: <List the projects here>
    Technical skills: <List the technical skills here>
    Soft skills: <List the soft skills here>
    Responsibilities: <List the responsibilities here>
    Certifications: <List the certifications here>
    Achievements: <List the achievements here>
\"\"\"{df4}\"\"\"
"""
response4 = get_completion(prompt)
print(response4)
# Out:
# Name: Siddhant Majumder
# Email: siddhantmajumder@gmail.com
# Phone number: 8240884229
# LinkedIn: linkedin.com/in/siddhant-majumder-6301161a1
# GitHub: github.com/Codeworm08
# Education:
# Master Of Computer Application Jadavpur University 11/2022 - Present,
# Bachelor Of Science in Computer Science St. Xavier's College(Autonomous) 04/2019 - 04/2022, 8.38 GPA
# Personal projects: Podcast Player (10/2023 - 10/2023), Movie Recommendation (07/2023 - 07/2023), Facebook Scrapper (10/2021 - 04/2022), Random Quote Generator using React
# Technical skills: Basic MongoDB, Git, Basic React, Basic Nodejs, Python Notebooks, Basic JavaScript, Basic Python
# Soft skills:
# Responsibilities:
# Certifications: Cloud Skills Boost Proﬁle Google IT Automation Certiﬁcate (06/2022 - 07/2022), FreeCodeCamp JavaScript Data Structures and Algorithms (10/2021 - 11/2021), The Complete Python Bootcamp From Zero

# %%
#convert all the above information in JSON format
import json

def text_to_json(text):
    # Split the text into lines
    lines = text.splitlines()

    # Create a dictionary to hold the key-value pairs
    data = {}
    current_key = None
    current_value = []

    # Iterate through each line
    for line in lines:
        # Check if the line contains a key-value pair (with a ":")
        if ":" in line:
            # If there's a current key, save its value before moving to the next key
            if current_key:
                data[current_key] = "\n".join(current_value).strip()
            
            # Split the line into key and the beginning of the value
            key, value = line.split(":", 1)
            current_key = key.strip()
            current_value = [value.strip()]
        else:
            # If there's no ":", treat this line as a continuation of the current value
            current_value.append(line.strip())

    # After the loop, save the last key-value pair
    if current_key:
        data[current_key] = "\n".join(current_value).strip()

    # Convert the dictionary to a JSON string
    json_data = json.dumps(data, indent=4)

    return json_data

json_output = text_to_json(response)
print(json_output)
# Out:
# {
#     "Name": "Aritra Adhya",
#     "Email": "aritraadhya1@gmail.com",
#     "Phone number": "8617245605",
#     "LinkedIn": "linkedin.com/in/aritraadhya",
#     "GitHub": "github.com/Aritraadhya",
#     "Education": "Master of Computer Application Jadavpur University 2022 - 2024, 8.24CGPA\nBachelor of Mathematics Jogesh Chandra Chaudhuri College 2017 - 2021, 68.625%\nHigher Secondary Examination Kalyani Central Model School 2015 - 2017, 70.8%\nSecondary Examination Nava Nalanda School 2014 - 2015, 77%",
#     "Personal projects": "Quiz App, Covid 19 detection using Multiscale CNN, Classi\ufb01cation model, To do list app, Tic-tac-toe app",
#     "Technical skills": "NumPy, Linux, C, C++, Java, Data Structures and Algorithms, HTML, CSS, Pandas, Bootstrap, Javascript, Python, Machine Learning, My SQL, Github, React.js",
#     "Soft skills": "",
#     "Responsibilities": "",
# ...

# %%
#convert all the above information in JSON format
import json

def text_to_json(text):
    # Split the text into lines
    lines = text.splitlines()

    # Create a dictionary to hold the key-value pairs
    data = {}
    current_key = None
    current_value = []

    # Iterate through each line
    for line in lines:
        # Check if the line contains a key-value pair (with a ":")
        if ":" in line:
            # If there's a current key, save its value before moving to the next key
            if current_key:
                data[current_key] = "\n".join(current_value).strip()
            
            # Split the line into key and the beginning of the value
            key, value = line.split(":", 1)
            current_key = key.strip()
            current_value = [value.strip()]
        else:
            # If there's no ":", treat this line as a continuation of the current value
            current_value.append(line.strip())

    # After the loop, save the last key-value pair
    if current_key:
        data[current_key] = "\n".join(current_value).strip()

    # Convert the dictionary to a JSON string
    json_data = json.dumps(data, indent=4)

    return json_data

json_output1 = text_to_json(response1)
print(json_output1)
# Out:
# {
#     "Name": "Nilesh Kundu",
#     "Email": "nileshkundu2@gmail.com",
#     "Phone number": "9382835462",
#     "LinkedIn": "linkedin.com/in/nilesh-kundu",
#     "GitHub": "github.com/ni1eshkundu",
#     "Education": "Master of Computer Application from Jadavpur University, Kolkata, 09/2022 - Present\nB.Sc in Computer Science from J.K College, Purulia, 07/2019 - 07/2022, CGPA-9.48\nHigher Secondary Education from Chittaranjan High School, Purulia, 07/2017 - 05/2019, 72.8%",
# ...

# %%
#convert all the above information in JSON format
import json

def text_to_json(text):
    # Split the text into lines
    lines = text.splitlines()

    # Create a dictionary to hold the key-value pairs
    data = {}
    current_key = None
    current_value = []

    # Iterate through each line
    for line in lines:
        # Check if the line contains a key-value pair (with a ":")
        if ":" in line:
            # If there's a current key, save its value before moving to the next key
            if current_key:
                data[current_key] = "\n".join(current_value).strip()
            
            # Split the line into key and the beginning of the value
            key, value = line.split(":", 1)
            current_key = key.strip()
            current_value = [value.strip()]
        else:
            # If there's no ":", treat this line as a continuation of the current value
            current_value.append(line.strip())

    # After the loop, save the last key-value pair
    if current_key:
        data[current_key] = "\n".join(current_value).strip()

    # Convert the dictionary to a JSON string
    json_data = json.dumps(data, indent=4)

    return json_data

json_output2 = text_to_json(response2)
print(json_output2)
# Out:
# {
#     "Name": "Priyanka Ghosh",
#     "Email": "priyanka7890mili@gmail.com",
#     "Phone number": "9875655122",
#     "LinkedIn": "linkedin.com/in/priyankaghosh25",
#     "GitHub": "github.com/Priyankaghosh25",
#     "Education": "Master of Computer Application (MCA), Jadavpur University, 09/2022 - 08/2023, SGPA - 8.67 (upto Sem-II), Bachelor of Science (Computer Science), Asutosh College (University of Calcutta), 07/2019 - 07/2022, CGPA- 9.071, Higher Secondary Examination (WBCHSE), Uttarpara Girls' High School, West Bengal, 2019,  Percentage - 89.2%, Secondary Examination (WBBSE), Uttarpara Children's Own Home, West Bengal, 2017, Percentage - 91.3%",
#     "Personal projects": "Study of Vehicle Routing Problem for Shipment Delivery, Hotel Booking Website, Real-Time Responsive Chat Application, Google Keep Clone",
#     "Technical skills": "C, C++ (intermediate), Java (basic), Python (basic), SQL, HTML, CSS, JavaScript, Socket.io, React.js, Node.js, MongoDB,"
# }

# %%
#convert all the above information in JSON format
import json

def text_to_json(text):
    # Split the text into lines
    lines = text.splitlines()

    # Create a dictionary to hold the key-value pairs
    data = {}
    current_key = None
    current_value = []

    # Iterate through each line
    for line in lines:
        # Check if the line contains a key-value pair (with a ":")
        if ":" in line:
            # If there's a current key, save its value before moving to the next key
            if current_key:
                data[current_key] = "\n".join(current_value).strip()
            
            # Split the line into key and the beginning of the value
            key, value = line.split(":", 1)
            current_key = key.strip()
            current_value = [value.strip()]
        else:
            # If there's no ":", treat this line as a continuation of the current value
            current_value.append(line.strip())

    # After the loop, save the last key-value pair
    if current_key:
        data[current_key] = "\n".join(current_value).strip()

    # Convert the dictionary to a JSON string
    json_data = json.dumps(data, indent=4)

    return json_data

json_output3 = text_to_json(response3)
print(json_output3)
# Out:
# {
#     "Name": "Rounik Majumder",
#     "Email": "rsmajumder704@gmail.com",
#     "Phone number": "+91 8902370152",
#     "LinkedIn": "linkedin.com/in/rounik-majumder",
#     "GitHub": "github.com/rsmajumder",
#     "Education": "",
#     "1. Jadavpur University, Master of Computer Application (MCA), 2022 - Present, CGPA": "8.005",
#     "2. University of Calcutta, Bachelor of Science | Computer Science, 2019 - 2022, CGPA": "8.36",
#     "3. Nebadhai High School, 12th, 2019, CGPA": "8.02",
#     "4. Nebadhai High School, 10th, 2017, CGPA": "9.1",
#     "Personal projects": "1. Build real time authentication system using Django REST API | OAuth 2.0, JWT , OTP system .\n2. Designing Ecommerce Website Using Django | Build Search System , Add to Cart , Show Product, Place to Order .\n3. Text-To-Speech Using HTML , CSS , JAVASCRIPT | Text to speech multiple language support ."
# }

# %%
print(response)
# Out:
# Name: Aritra Adhya
# Email: aritraadhya1@gmail.com
# Phone number: 8617245605
# LinkedIn: linkedin.com/in/aritraadhya
# GitHub: github.com/Aritraadhya
# Education: Master of Computer Application Jadavpur University 2022 - 2024, 8.24CGPA Bachelor of Mathematics Jogesh Chandra Chaudhuri College 2017 - 2021, 68.625% Higher Secondary Examination Kalyani Central Model School 2015 - 2017, 70.8% Secondary Examination Nava Nalanda School 2014 - 2015, 77%
# Personal projects: Quiz App, Covid 19 detection using Multiscale CNN, Classiﬁcation model, To do list app, Tic-tac-toe app
# Technical skills: NumPy, Linux, C, C++, Java, Data Structures and Algorithms, HTML, CSS, Pandas, Bootstrap, Javascript, Python, Machine Learning, My SQL, Github, React.js
# Soft skills:
# Responsibilities:
# Certifications: C LinkdIn Skill Assessment, C++ Intermediate Certiﬁcate TechGig, Problem Solving Hackerrank certiﬁ

# %%
#convert all the above information in JSON format
import json

def text_to_json(text):
    # Split the text into lines
    lines = text.splitlines()

    # Create a dictionary to hold the key-value pairs
    data = {}
    current_key = None
    current_value = []

    # Iterate through each line
    for line in lines:
        # Check if the line contains a key-value pair (with a ":")
        if ":" in line:
            # If there's a current key, save its value before moving to the next key
            if current_key:
                data[current_key] = "\n".join(current_value).strip()
            
            # Split the line into key and the beginning of the value
            key, value = line.split(":", 1)
            current_key = key.strip()
            current_value = [value.strip()]
        else:
            # If there's no ":", treat this line as a continuation of the current value
            current_value.append(line.strip())

    # After the loop, save the last key-value pair
    if current_key:
        data[current_key] = "\n".join(current_value).strip()

    # Convert the dictionary to a JSON string
    json_data = json.dumps(data, indent=4)

    return json_data

json_output4 = text_to_json(response4)
print(json_output4)
# Out:
# {
#     "Name": "Siddhant Majumder",
#     "Email": "siddhantmajumder@gmail.com",
#     "Phone number": "8240884229",
#     "LinkedIn": "linkedin.com/in/siddhant-majumder-6301161a1",
#     "GitHub": "github.com/Codeworm08",
#     "Education": "Master Of Computer Application Jadavpur University 11/2022 - Present,\nBachelor Of Science in Computer Science St. Xavier's College(Autonomous) 04/2019 - 04/2022, 8.38 GPA",
#     "Personal projects": "Podcast Player (10/2023 - 10/2023), Movie Recommendation (07/2023 - 07/2023), Facebook Scrapper (10/2021 - 04/2022), Random Quote Generator using React",
#     "Technical skills": "Basic MongoDB, Git, Basic React, Basic Nodejs, Python Notebooks, Basic JavaScript, Basic Python",
#     "Soft skills": "",
#     "Responsibilities": "",
# ...

# %%
pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.2 MB 2.3 MB/s eta 0:00:01
#    -------- ------------------------------- 0.2/1.2 MB 3.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.2 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 4.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# Database connection parameters
conn_params = {
    "host": "localhost",
    "user": "root",
    "password": "qwerty",  # Replace with your MySQL password
    "database": "db",  # Replace with your MySQL database name
    "port": 3306  # MySQL default port
}

try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")
        cur = conn.cursor()
        cur.execute("SELECT VERSION();")
        db_version = cur.fetchone()
        print(f"Database version: {db_version}")
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error connecting to MySQL: {e}")
# Out:
# Connected to MySQL successfully!
# Database version: ('8.0.39',)

# %%
# Assume conn and cur are your existing connection and cursor

# Define the SQL statement to create a new table


try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()
        
        # Define the SQL statement to create a new table
        create_table_query = """
        CREATE TABLE resume_bot (
        Name varchar(50),
        email varchar(50) PRIMARY KEY,
        Phone_number varchar(50),LinkedIn varchar(50),GitHub varchar(50),Education varchar(1000),Personal_projects varchar(500),Technical_skills varchar(500),Soft_skills varchar(500),Responsibilities varchar(500),Certifications varchar(500),Achievements varchar(500)
        );
    """
        
        # Execute the SQL statement to create the new table
        cur.execute(create_table_query)
        print("Table 'resume_bot' created successfully!")
        
        # Commit changes
        conn.commit()

        # Close the cursor and connection
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# Connected to MySQL successfully!
# Table 'resume_bot' created successfully!

# %%
# SQL statement to insert data
insert_data_query = """
INSERT INTO resume_bot (Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects,Technical_skills,Soft_skills,Responsibilities) VALUES ("Aritra Adhya","aritraadhya1@gmail.com","8617245605","linkedin.com/in/aritraadhya","github.com/Aritraadhya","1. Master of Computer Application Jadavpur University 2022 - 2024, 8.24CGPA\n2. Bachelor of Mathematics Jogesh Chandra Chaudhuri College 2017 - 2021, 68.625%\n3. Higher Secondary Examination Kalyani Central Model School 2015 - 2017, 70.8%\n4. Secondary Examination Nava Nalanda School 2014 - 2015, 77%","1. Quiz App\n2. Covid 19 detection using Multiscale CNN\n3. Classification model\n4. To do list app\n5. Tic-tac-toe app","NumPy, Linux, C, C++, Java, Data Structures and Algorithms, HTML, CSS, Pandas, Bootstrap, Javascript, Python, Machine Learning, MySQL, Github, React.js", "Passionate programming, eager to learn new technologies","Passionate programmer");
"""

try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()

        # Execute the SQL statement to insert data
        cur.execute(insert_data_query)
        print("Data inserted successfully!")

        # Commit changes
        conn.commit()

        # Close the cursor and connection
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# Connected to MySQL successfully!
# Data inserted successfully!

# %%
insert_data_query = """
INSERT INTO resume_bot (Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects,Technical_skills,Soft_skills,Responsibilities,Certifications,Achievements) VALUES ("Nilesh Kundu","nileshkundu2@gmail.com","9382835462","linkedin.com/in/nilesh-kundu","github.com/ni1eshkundu","Master of Computer Application - Jadavpur University, B.Sc in Computer Science - J.K College, Purulia, Higher Secondary Education - Chittaranjan High School, Purulia","Real-Time Chat Application, Design a University Website","C, C++, Python(Basic), java(Basic), OS, javascript(Basic), React.js, DBMS, OOPS, HTML, CSS, Problem Solving", "None","None","Problem Solving (Basic) Certificate, SQL (Basic) Certificate, Microsoft Learn Student Embassador","Achieved GMR 25 in WBJECA");
"""

try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()

        # Execute the SQL statement to insert data
        cur.execute(insert_data_query)
        print("Data inserted successfully!")

        # Commit changes
        conn.commit()

        # Close the cursor and connection
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# Connected to MySQL successfully!
# Data inserted successfully!

# %%
insert_data_query = """
INSERT INTO resume_bot (Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects,Technical_skills,Soft_skills,Responsibilities,Certifications) VALUES ("Priyanka Ghosh","priyanka7890mili@gmail.com","9875655122","linkedin.com/in/priyankaghosh25","github.com/Priyankaghosh25","Master of Computer Application (MCA) from Jadavpur University, SGPA - 8.67 (upto Sem-II), Bachelor of Science (Computer Science) from Asutosh College ( University of Calcutta ), CGPA- 9.071, Higher Secondary Examination (WBCHSE) from Uttarpara Girls' High School, West Bengal  Percentage - 89.2%, Secondary Examination (WBBSE) from Uttarpara Children's Own Home, West Bengal  Percentage - 91.3%","Study of Vehicle Routing Problem for Shipment Delivery, Hotel Booking Website, Real-Time Responsive Chat Application, Google Keep Clone","C, C++, Java, Python, SQL, HTML, CSS, JavaScript, Socket.io, React.js, Node.js, MongoDB, Express.js","N/A","N/A","GMR 6 in WB JECA 2022 Examination, Gold Badge from Celebal Technologies");
"""

try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()

        # Execute the SQL statement to insert data
        cur.execute(insert_data_query)
        print("Data inserted successfully!")

        # Commit changes
        conn.commit()

        # Close the cursor and connection
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# Connected to MySQL successfully!
# Data inserted successfully!

# %%
insert_data_query = """
INSERT INTO resume_bot (Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects) VALUES ("Rounik Majumder","rsmajumder704@gmail.com","+91 8902370152","linkedin.com/in/rounik-majumder","github.com/rsmajumder","Jadavpur University Master of Computer Application (MCA) 2022 - Present, CGPA : 8.005, University of Calcutta Bachelor of Science | Computer Science 2019 - 2022, CGPA : 8.36, Nebadhai High School 12th 2019, CGPA : 8.02, Nebadhai High School 10th 2017, CGPA : 9.1","Build real time authentication system USING DJANGO REST API | OAuth 2.0, JWT , OTP system ., Designing Ecommerce Website Using Django | Build Search System , Add to Cart , Show Product, Place to Order ., Text-To-Speech Using HTML , CSS , JAVASCRIPT | Text to speech multiple language support ., Real Time Chat Application Using Django | MVT Architecture | Create Room | User End to End Chating in real time ., Jeca Cracker");
"""

try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()

        # Execute the SQL statement to insert data
        cur.execute(insert_data_query)
        print("Data inserted successfully!")

        # Commit changes
        conn.commit()

        # Close the cursor and connection
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# Connected to MySQL successfully!
# Data inserted successfully!

# %%
insert_data_query = """
INSERT INTO resume_bot (Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects,Technical_skills,Soft_skills,Responsibilities,Certifications) VALUES ("Siddhant Majumder","siddhantmajumder@gmail.com","8240884229","linkedin.com/in/siddhant-majumder-6301161a1","github.com/Codeworm08","Master Of Computer Application, Jadavpur University ,11/2022 - Present, Bachelor Of Science in Computer Science ,St. Xavier's College(Autonomous) 04/2019 - 04/2022, 8.38 GPA","1) Podcast Player (10/2023 - 10/2023) 2) Movie Recommendation (07/2023 - 07/2023) 3) Facebook Scrapper (10/2021 - 04/2022) 4) Random Quote Generator using React","Basic MongoDB, Git, Basic React, Basic Nodejs, Python Notebooks, Basic JavaScript, Basic Python","N/A","N/A","Cloud Skills Boost Proﬁle, Google IT Automation Certiﬁcate (06/2022 - 07/2022), FreeCodeCamp JavaScript Data Structures and Algorithms (10");
"""

try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()

        # Execute the SQL statement to insert data
        cur.execute(insert_data_query)
        print("Data inserted successfully!")

        # Commit changes
        conn.commit()

        # Close the cursor and connection
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 try:
#       6     # Establish a connection to the database
# ----> 7     conn = mysql.connector.connect(**conn_params)
#       8     if conn.is_connected():
#
# NameError: name 'mysql' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      22         cur.close()
#      23         conn.close()
# ---> 24 except mysql.connector.Error as e:
#      25     print(f"Error: {e}")
#
# NameError: name 'mysql' is not defined

# %%
insert_data_query = """
INSERT INTO resume_bot (Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects,Technical_skills,Soft_skills,Responsibilities,Certifications) VALUES ("Priyanka Ghosh","priyanka7890mili@gmail.com","9875655122","linkedin.com/in/priyankaghosh25","github.com/Priyankaghosh25","Master of Computer Application (MCA) from Jadavpur University, SGPA - 8.67 (upto Sem-II), Bachelor of Science (Computer Science) from Asutosh College ( University of Calcutta ), CGPA- 9.071, Higher Secondary Examination (WBCHSE) from Uttarpara Girls' High School, West Bengal  Percentage - 89.2%, Secondary Examination (WBBSE) from Uttarpara Children's Own Home, West Bengal  Percentage - 91.3%","Study of Vehicle Routing Problem for Shipment Delivery, Hotel Booking Website, Real-Time Responsive Chat Application, Google Keep Clone","C, C++, Java, Python, SQL, HTML, CSS, JavaScript, Socket.io, React.js, Node.js, MongoDB, Express.js","N/A","N/A","GMR 6 in WB JECA 2022 Examination, Gold Badge from Celebal Technologies");
"""
print(insert_data_query)
try:
    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()

        # Execute the SQL statement to insert data
        cur.execute(insert_data_query)
        print("Data inserted successfully!")

        # Commit changes
        conn.commit()

        # Close the cursor and connection
        cur.close()
        conn.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# INSERT INTO resume_bot (Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects,Technical_skills,Soft_skills,Responsibilities,Certifications) VALUES ("Priyanka Ghosh","priyanka7890mili@gmail.com","9875655122","linkedin.com/in/priyankaghosh25","github.com/Priyankaghosh25","Master of Computer Application (MCA) from Jadavpur University, SGPA - 8.67 (upto Sem-II), Bachelor of Science (Computer Science) from Asutosh College ( University of Calcutta ), CGPA- 9.071, Higher Secondary Examination (WBCHSE) from Uttarpara Girls' High School, West Bengal  Percentage - 89.2%, Secondary Examination (WBBSE) from Uttarpara Children's Own Home, West Bengal  Percentage - 91.3%","Study of Vehicle Routing Problem for Shipment Delivery, Hotel Booking Website, Real-Time Responsive Chat Application, Google Keep Clone","C, C++, Java, Python, SQL, HTML, CSS, JavaScript, Socket.io, React.js, Node.js, MongoDB, Express.js","N/A","N/A","GMR 6 in WB JECA 2022 Examination, Gold Badge from Celebal Techn
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/14.3 MB 1.3 MB/s eta 0:00:11
#     --------------------------------------- 0.2/14.3 MB 2.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/14.3 MB 5.6 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/14.3 MB 5.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/14.3 MB 4.9 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/14.3 MB 5.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/14.3 MB 5.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/14.3 MB 5.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/14.3 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/14.3 MB 3.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.9/14.3 MB 3.7 MB/s eta 0:00:04
# ...

# %%
import mysql.connector

# %%
import mysql.connector
import json

# JSON object strings

# Decode JSON strings into Python dictionaries
json_o = json.loads(json_output)
json_o1 = json.loads(json_output1)
json_o2 = json.loads(json_output2)
json_o3 = json.loads(json_output3)
json_o4 = json.loads(json_output4)

# Collect the decoded JSON objects into a list
json_d = [json_o,json_o1,json_o2,json_o3,json_o4]

try:
    # Connection parameters (replace with your actual parameters

    # Establish a connection to the database
    conn = mysql.connector.connect(**conn_params)
    if conn.is_connected():
        print("Connected to MySQL successfully!")

        # Create a cursor object
        cur = conn.cursor()

        # Dynamically insert each JSON object into the database
        for entry in json_d:
            print(type(entry.values()))
            # Extract column names and values from each JSON object
            columns = ','.join(entry.keys())  # Column names (e.g., 'first_name, last_name, email')
            placeholders = ','.join(['%s'] * len(entry))  # Placeholders for values (e.g., '%s, %s, %s')
            values = tuple(entry.values())  # Actual values (e.g., ('John', 'Doe', 'john.doe@example.com'))
            columns=columns.replace(' ','_')
            print(columns)
            print(values)
            s=str(values)
            print(type(s))
            print(type(columns))
            print(s)
            # SQL query to insert data into the table (assuming table name is 'resume_bot')'''
            insert_data_query = """INSERT INTO resume_bot ("""+columns+""")"""+""" VALUES """+s+""";"""
            if insert_data_query[len(insert_data_query)-1]!=';':
                insert_data_query=insert_data_query+';'
            print(type(insert_data_query))
            print(insert_data_query)

            # Execute the insert query
            cur.execute(insert_data_query)

        # Commit the transaction
        conn.commit()
        print(f"Inserted {cur.rowcount} rows successfully!")

        # Close the cursor and connection
        cur.close()
        conn.close()

except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# Connected to MySQL successfully!
# <class 'dict_values'>
# Name,Email,Phone_number,LinkedIn,GitHub,Education,Personal_projects,Technical_skills,Soft_skills,Responsibilities,Certifications
# ('Aritra Adhya', 'aritraadhya1@gmail.com', '8617245605', 'linkedin.com/in/aritraadhya', 'github.com/Aritraadhya', 'Master of Computer Application Jadavpur University 2022 - 2024, 8.24CGPA Bachelor of Mathematics Jogesh Chandra Chaudhuri College 2017 - 2021, 68.625% Higher Secondary Examination Kalyani Central Model School 2015 - 2017, 70.8% Secondary Examination Nava Nalanda School 2014 - 2015, 77%', 'Quiz App, Covid 19 detection using Multiscale CNN, Classiﬁcation model, To do list app, Tic-tac-toe app', 'NumPy, Linux, C, C++, Java, Data Structures and Algorithms, HTML, CSS, Pandas, Bootstrap, Javascript, Python, Machine Learning, My SQL, Github, React.js', '', '', 'C LinkdIn Skill Assessment, C++ Intermediate Certiﬁcate TechGig, Problem Solving Hackerrank certiﬁ')
# <class 'str'>
# ...

# %%
print(json_output)
# Out:
# {
#     "Name": "Aritra Adhya",
#     "Email": "aritraadhya1@gmail.com",
#     "Phone number": "8617245605",
#     "LinkedIn": "linkedin.com/in/aritraadhya",
#     "GitHub": "github.com/Aritraadhya",
#     "Education": "Master of Computer Application Jadavpur University 2022 - 2024, 8.24CGPA Bachelor of Mathematics Jogesh Chandra Chaudhuri College 2017 - 2021, 68.625% Higher Secondary Examination Kalyani Central Model School 2015 - 2017, 70.8% Secondary Examination Nava Nalanda School 2014 - 2015, 77%",
#     "Personal projects": "Quiz App, Covid 19 detection using Multiscale CNN, Classi\ufb01cation model, To do list app, Tic-tac-toe app",
#     "Technical skills": "NumPy, Linux, C, C++, Java, Data Structures and Algorithms, HTML, CSS, Pandas, Bootstrap, Javascript, Python, Machine Learning, My SQL, Github, React.js",
#     "Soft skills": "",
#     "Responsibilities": "",
# ...

# %%
print(json_output1)
# Out:
# {
#     "Name": "Nilesh Kundu",
#     "Email": "nileshkundu2@gmail.com",
#     "Phone number": "9382835462",
#     "LinkedIn": "linkedin.com/in/nilesh-kundu",
#     "GitHub": "github.com/ni1eshkundu",
#     "Education": "Master of Computer Application, Jadavpur University (09/2022 - Present), Kolkata, B.Sc in Computer Science, J.K College, Purulia (07/2019 - 07/2022), CGPA-9.48, Higher Secondary Education Chittaranjan High School, Purulia (07/2017 - 05/2019), 72.8%",
#     "Personal projects": "Real-Time Chat Application (08/2023 - 09/2023), Design a University Website (03/2022 - 06/2022)",
#     "Technical skills": "C, C++, Python(Basic), java(Basic), OS, javascript(Basic), React.js, DBMS, OOPS, HTML, CSS, Problem Solving",
#     "Soft skills": "N/A",
#     "Responsibilities": "N/A",
#     "Certifications": "Problem Solving (Basic) Certificate, SQL (Basic) Certificate, Microsoft Learn Student Embassador",
#     "Achievements": "Achieved GMR 25 in WBJECA"
# }

# %%
print(json_output2)
# Out:
# {
#     "Name": "Priyanka Ghosh",
#     "Email": "priyanka7890mili@gmail.com",
#     "Phone number": "9875655122",
#     "LinkedIn": "linkedin.com/in/priyankaghosh25",
#     "GitHub": "github.com/Priyankaghosh25",
#     "Education": "Master of Computer Application (MCA), Jadavpur University; Bachelor of Science (Computer Science), Asutosh College (University of Calcutta); Higher Secondary Examination (WBCHSE), Uttarpara Girls' High School; Secondary Examination (WBBSE), Uttarpara Children's Own Home",
#     "Personal projects": "Study of Vehicle Routing Problem for Shipment Delivery, Hotel Booking Website, Real-Time Responsive Chat Application, Google Keep Clone",
#     "Technical skills": "C, C++, Java, Python, SQL, HTML, CSS, JavaScript, Socket.io, React.js, Node.js, MongoDB, Express.js",
#     "Soft skills": "N/A",
#     "Responsibilities": "N/A",
#     "Certifications": "GMR 6 in WB JECA 2022 Examination",
# ...

# %%
print(json_output3)
# Out:
# {
#     "Name": "Rounik Majumder",
#     "Email": "rsmajumder704@gmail.com",
#     "Phone number": "+91 8902370152",
#     "LinkedIn": "linkedin.com/in/rounik-majumder",
#     "GitHub": "github.com/rsmajumder",
#     "Education": "Master of Computer Application (MCA), Jadavpur University, CGPA : 8.005, 2022 - Present; Bachelor of Science | Computer Science, University of Calcutta, CGPA : 8.36, 2019 - 2022; 12th, Nebadhai High School, CGPA : 8.02, 2019; 10th, Nebadhai High School, CGPA : 9.1, 2017",
#     "Personal projects": "Build real time authentication system Using Django REST API | OAuth 2.0, JWT , OTP system; Designing Ecommerce Website Using Django | Build Search System , Add to Cart , Show Product, Place to Order; Text-To-Speech Using HTML , CSS , JAVASCRIPT | Text to speech multiple language support; Real Time Chat Application Using Django | MVT Architecture | Create Room | User End to End Chating in real time; Jeca Cracker Html Css Java"
# }

# %%
print(json_output4)
# Out:
# {
#     "Name": "Siddhant Majumder",
#     "Email": "siddhantmajumder@gmail.com",
#     "Phone number": "8240884229",
#     "LinkedIn": "linkedin.com/in/siddhant-majumder-6301161a1",
#     "GitHub": "github.com/Codeworm08",
#     "Education": "Master Of Computer Application Jadavpur University, Bachelor Of Science in Computer Science St. Xavier's College(Autonomous), 8.38 GPA",
#     "Personal projects": "Podcast Player, Movie Recommendation, Facebook Scrapper, Random Quote Generator using React",
#     "Technical skills": "Basic MongoDB, Git, Basic React, Basic Nodejs, Python Notebooks, Basic JavaScript, Basic Python",
#     "Soft skills": "",
#     "Responsibilities": "Developed front end apps using react js framework making use of hooks, context and fetch api",
# ...

# %%
type(json_output)
# Out:
# str

# %%
json_ou={
    "Name": "Aritra Adhya",
    "Email": "aritraadhya1@gmail.com",
    "Phone number": "8617245605",
    "LinkedIn": "linkedin.com/in/aritraadhya",
    "GitHub": "github.com/Aritraadhya",
    "Education": "Master of Computer Application Jadavpur University 2022 - 2024, 8.24CGPA Bachelor of Mathematics Jogesh Chandra Chaudhuri College 2017 - 2021, 68.625% Higher Secondary Examination Kalyani Central Model School 2015 - 2017, 70.8% Secondary Examination Nava Nalanda School 2014 - 2015, 77%",
    "Personal projects": "Quiz App, Covid 19 detection using Multiscale CNN, Classi\ufb01cation model, To do list app, Tic-tac-toe app",
    "Technical skills": "NumPy, Linux, C, C++, Java, Data Structures and Algorithms, HTML, CSS, Pandas, Bootstrap, Javascript, Python, Machine Learning, My SQL, Github, React.js",
    "Soft skills": "",
    "Responsibilities": "",
    "Certifications": "C LinkdIn Skill Assessment, C++ Intermediate Certi\ufb01cate TechGig, Problem Solving Hackerrank certi\ufb01"
    
}
json_ou1={
    "Name": "Nilesh Kundu",
    "Email": "nileshkundu2@gmail.com",
    "Phone number": "9382835462",
    "LinkedIn": "linkedin.com/in/nilesh-kundu",
    "GitHub": "github.com/ni1eshkundu",
    "Education": "Master of Computer Application, Jadavpur University (09/2022 - Present), Kolkata, B.Sc in Computer Science, J.K College, Purulia (07/2019 - 07/2022), CGPA-9.48, Higher Secondary Education Chittaranjan High School, Purulia (07/2017 - 05/2019), 72.8%",
    "Personal projects": "Real-Time Chat Application (08/2023 - 09/2023), Design a University Website (03/2022 - 06/2022)",
    "Technical skills": "C, C++, Python(Basic), java(Basic), OS, javascript(Basic), React.js, DBMS, OOPS, HTML, CSS, Problem Solving",
    "Soft skills": "N/A",
    "Responsibilities": "N/A",
    "Certifications": "Problem Solving (Basic) Certificate, SQL (Basic) Certificate, Microsoft Learn Student Embassador",
    "Achievements": "Achieved GMR 25 in WBJECA"
}
json_ou2={
    "Name": "Priyanka Ghosh",
    "Email": "priyanka7890mili@gmail.com",
    "Phone number": "9875655122",
    "LinkedIn": "linkedin.com/in/priyankaghosh25",
    "GitHub": "github.com/Priyankaghosh25",
    "Education": "Master of Computer Application (MCA), Jadavpur University; Bachelor of Science (Computer Science), Asutosh College (University of Calcutta); Higher Secondary Examination (WBCHSE), Uttarpara Girls' High School; Secondary Examination (WBBSE), Uttarpara Children's Own Home",
    "Personal projects": "Study of Vehicle Routing Problem for Shipment Delivery, Hotel Booking Website, Real-Time Responsive Chat Application, Google Keep Clone",
    "Technical skills": "C, C++, Java, Python, SQL, HTML, CSS, JavaScript, Socket.io, React.js, Node.js, MongoDB, Express.js",
    "Soft skills": "N/A",
    "Responsibilities": "N/A",
    "Certifications": "GMR 6 in WB JECA 2022 Examination",
    "Achievements": "Received Gold Badge from Celebal Technologies, Secured 1st position during graduation in college\n\n# The output is not exactly as expected. The details of each field are not separated by commas and there is also an issue with"
}
json_ou3={
    "Name": "Rounik Majumder",
    "Email": "rsmajumder704@gmail.com",
    "Phone number": "+91 8902370152",
    "LinkedIn": "linkedin.com/in/rounik-majumder",
    "GitHub": "github.com/rsmajumder",
    "Education": "Master of Computer Application (MCA), Jadavpur University, CGPA : 8.005, 2022 - Present; Bachelor of Science | Computer Science, University of Calcutta, CGPA : 8.36, 2019 - 2022; 12th, Nebadhai High School, CGPA : 8.02, 2019; 10th, Nebadhai High School, CGPA : 9.1, 2017",
    "Personal projects": "Build real time authentication system Using Django REST API | OAuth 2.0, JWT , OTP system; Designing Ecommerce Website Using Django | Build Search System , Add to Cart , Show Product, Place to Order; Text-To-Speech Using HTML , CSS , JAVASCRIPT | Text to speech multiple language support; Real Time Chat Application Using Django | MVT Architecture | Create Room | User End to End Chating in real time; Jeca Cracker Html Css Java"
}
json_ou4={
    "Name": "Siddhant Majumder",
    "Email": "siddhantmajumder@gmail.com",
    "Phone number": "8240884229",
    "LinkedIn": "linkedin.com/in/siddhant-majumder-6301161a1",
    "GitHub": "github.com/Codeworm08",
    "Education": "Master Of Computer Application Jadavpur University, Bachelor Of Science in Computer Science St. Xavier's College(Autonomous), 8.38 GPA",
    "Personal projects": "Podcast Player, Movie Recommendation, Facebook Scrapper, Random Quote Generator using React",
    "Technical skills": "Basic MongoDB, Git, Basic React, Basic Nodejs, Python Notebooks, Basic JavaScript, Basic Python",
    "Soft skills": "",
    "Responsibilities": "Developed front end apps using react js framework making use of hooks, context and fetch api",
    "Certifications": "Google IT Automation Certi\ufb01cate, FreeCodeCamp JavaScript Data Structures and Algorithms, The Complete Python Bootcamp From Zero to Hero in Python, Jose Portilla's Python Boot Camp in Udemy, Google ExploreML, M001:MongoDB Basics",
    "Achievements": "Event head of cryptography event at Computer Science St. Xavier's College Departmental Fest Exabyte 2022, Solved 300+ problems in LeetCode, Gold Badge in Python"
}
json_output=json.dumps(json_ou,indent=4)
json_output1=json.dumps(json_ou1,indent=4)
json_output2=json.dumps(json_ou2,indent=4)
json_output3=json.dumps(json_ou3,indent=4)
json_output4=json.dumps(json_ou4,indent=4)
